# %% [markdown]
# # Problem Statement
#
# An education company named X Education sells online courses to industry profesionals. There are many visitors from various backgrounds landing to their website to explore around or even browse for courses that they will end up buying. These visitors are coming from different marketing channels like search ads in Google search result and ads in several websites. Once these people land on the website, besides doing what they want to do in the website, they can also fill up a form related to a course.
#
# When these people fill up a form providing their email or phone number, they are classified to be a lead. Moreover, the company also get leads from past referals.

# %%
# Import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set up library default setting
pd.options.display.max_columns = 0

# %%
# Import leads data dictionary
leads_dict = pd.read_excel('data/Leads Data Dictionary.xlsx')
leads_dict
# Out:
#     Unnamed: 0  ...                                         Unnamed: 2
# 0          NaN  ...                                                NaN
# 1          NaN  ...                                        Description
# 2          NaN  ...  A unique ID with which the customer is identif...
# 3          NaN  ...      A lead number assigned to each lead procured.
# 4          NaN  ...  The origin identifier with which the customer ...
# 5          NaN  ...  The source of the lead. Includes Google, Organ...
# 6          NaN  ...  An indicator variable selected by the customer...
# 7          NaN  ...  An indicator variable selected by the customer...
# 8          NaN  ...  The target variable. Indicates whether a lead ...
# 9          NaN  ...  The total number of visits made by the custome...
# 10         NaN  ...  The total time spent by the customer on the we...
# 11         NaN  ...  Average number of pages on the website viewed ...
# ...

# %% [markdown]
# Eventually, this data is

# %%
# Import leads data
leads_dat = pd.read_csv('data/Leads.csv')
leads_dat
# Out:
#                                Prospect ID  ...  Last Notable Activity
# 0     7927b2df-8bba-4d29-b9a2-b6e0beafe620  ...               Modified
# 1     2a272436-5132-4136-86fa-dcc88c88f482  ...           Email Opened
# 2     8cc8c611-a219-4f35-ad23-fdfd2656bd8a  ...           Email Opened
# 3     0cc2df48-7cf4-4e39-9de9-19797f9b38cc  ...               Modified
# 4     3256f628-e534-4826-9d63-4a8b88782852  ...               Modified
# ...                                    ...  ...                    ...
# 9235  19d6451e-fcd6-407c-b83b-48e1af805ea9  ...      Email Marked Spam
# 9236  82a7005b-7196-4d56-95ce-a79f937a158d  ...               SMS Sent
# 9237  aac550fe-a586-452d-8d3c-f1b62c94e02c  ...               SMS Sent
# 9238  5330a7d1-2f2b-4df4-85d6-64ca2f6b95b9  ...               SMS Sent
# 9239  571b5c8e-a5b2-4d57-8574-f2ffb06fdeff  ...               Modified
#
# [9240 rows x 37 columns]

# %%
leads_dat['Lead Origin'].unique()
# Out:
# array(['API', 'Landing Page Submission', 'Lead Add Form', 'Lead Import',
#        'Quick Add Form'], dtype=object)
